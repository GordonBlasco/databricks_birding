# %%
# %sql
CREATE SCHEMA birds.ebird_bronze

# %%
# %sql
DROP table if exists birds.ebird_bronze.checklist_index;
DROP table if exists birds.ebird_bronze.checklist_detail;

# %%
secret = dbutils.secrets.get(scope="ebird", key="api_key")
invisible_sep = bytes.fromhex("E281A3").decode("utf-8")
plaintextSecret = secret.replace("", invisible_sep)
print(plaintextSecret)
